# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/endurance/2bpc_bwa_3028_cb_16att_1cells_endurance_fast.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
for aliaspt in data[data["failures"].diff() < 0].index.values:
    data.loc[data.index >= aliaspt, "failures"] = data.loc[data.index >= aliaspt, "failures"] + 2**32
plt.plot(data["successes"], 37*data["successes"].diff()/(data["cycles"].diff()*10e-9) * 2)
plt.xscale("log")
plt.show()
plt.plot(data["successes"], data["failures"]/data["successes"]/37)
plt.xscale("log")

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/endurance/1bpc_bwa_0_cb_16att_1cells_endurance_fast.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
for aliaspt in data[data["failures"].diff() < 0].index.values:
    data.loc[data.index >= aliaspt, "failures"] = data.loc[data.index >= aliaspt, "failures"] + 2**32
plt.plot(data["successes"], 37*data["successes"].diff()/(data["cycles"].diff()*10e-9) * 1)
plt.xscale("log")
plt.show()
plt.plot(data["successes"], data["failures"]/data["successes"]/37)
plt.xscale("log")
