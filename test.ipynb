# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/endurance/1bpc_bwa_0_cb_16att_1024cells_endurance.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
data.plot("cycles", "successes")
data.plot("cycles", "failures")
plt.show()
plt.plot(data["successes"]/1024, data["successes"].diff()/(data["cycles"].diff()*10e-9))
plt.plot(data["successes"]/1024, data["failures"].diff()/(data["cycles"].diff()*10e-9))

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/endurance/1bpc_bwa_0_cb_16att_1cells_endurance.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
data.plot("cycles", "successes")
data.plot("cycles", "failures")
plt.show()
plt.plot(data["successes"], 37*data["successes"].diff()/(data["cycles"].diff()*10e-9))
plt.show()
plt.plot(data["successes"], data["failures"]/data["successes"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3830056/1735552129.py in <module>
#       2 import pandas as pd
#       3
# ----> 4 data = pd.read_csv("data/endurance/2bpc_bwa_0_cb_16att_1cells_endurance.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
#       5 data.plot("cycles", "successes")
#       6 data.plot("cycles", "failures")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/endurance/2bpc_bwa_3028_cb_16att_1cells_endurance.csv", delimiter="\t", names=["t", "successes", "failures", "reads", "sets", "resets", "cycles", "read_bits", "set_bits", "reset_bits", ])
data.plot("cycles", "successes")
data.plot("cycles", "failures")
plt.show()
plt.plot(data["successes"], 37*data["successes"].diff()/(data["cycles"].diff()*10e-9) * 2)
plt.show()
plt.plot(data["successes"], data["failures"]/data["successes"]/4)
